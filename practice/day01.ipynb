# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import norm

# %%
# 消除默认打印地址的方法
x = np.arange(-5,5,0.02)
y = norm.pdf(x,0,1)

fig,ax = plt.subplots()
ax.plot(x,y,label='norm_distri')
ax.legend();
# 在代码块最后加一个分号;
# 在代码块最后加一句plt.show()
# 在绘图时将绘图对象显式赋值给一个变量，如将plt.plot([1, 2, 3, 4]) 改成line =plt.plot([1, 2, 3, 4])

# %% [markdown]
# ### 两种绘图模式
#     - OO模式
#     - plt调用模式

# %%
# OO模式
x = np.linspace(0,2,100)
fig,ax = plt.subplots()
ax.plot(x,x,label='linear')
ax.plot(x,x**2,label='quadratic')
ax.plot(x,x**3,label='cubic')
ax.set_xlabel('x_label')
ax.set_ylabel('y_label')
ax.set_title('Simple_Plot')
ax.legend();

# %%
# 依赖pyplot调用模式
x = np.linspace(0,2,100)

plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('x_label')
plt.ylabel('y_label')
plt.title('Simple_Plot')
plt.legend() # 显示图列
plt.show()

# %% [markdown]
# ### 通用模板
#     - step1 准备数据
#     - step2 设置绘图样式
#     - step3 定义布局
#     - step4 绘制图像
#     - step5 添加标签，文字和图例

# %%
# step1 准备数据
x = np.linspace(1,2,100)
y = x**2
# step2 设置绘图样式
mpl.rc('lines',linewidth=2,linestyle='--')
# step3 定义布局
fig,ax = plt.subplots()
# 绘制图形
ax.plot(x,y,label='linear',color='pink')
# 添加标签，文字和图例
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('Simple_plot')
ax.legend();

# %%
# 使用plt模式绘图
# step1 准备数据
x = np.linspace(0,2,100)
y = norm.pdf(x,loc=1)
# step2 设置绘图样式
mpl.rc('lines',lw=3,ls='-.')
# step3绘制图形
plt.plot(x,y,label='norm',color='blue')
# step4添加标签，文字和图例
plt.xlabel('x_label')
plt.ylabel('y_label')
plt.title('Simple_plot')
plt.legend();
